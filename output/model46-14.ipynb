# %%
from functions import model46 as cnn

# %%
cnn(14)
# Out:
# INDEX:  14
# Used Channels:  46
# [36, 38, 7, 8, 11, 12, 44, 14, 49, 19, 51, 53, 24, 56, 28, 29]
# ['15_20150508.mat', '8_20151103.mat', '12_20150725.mat', '6_20150507.mat', '7_20150715.mat', '10_20151014.mat', '11_20150916.mat', '5_20160406.mat', '9_20151028.mat', '2_20150915.mat', '1_20160518.mat', '3_20150919.mat', '4_20151111.mat', '14_20151205.mat', '13_20151115.mat']
# 15_20150508.mat
# 8_20151103.mat
# 12_20150725.mat
# 6_20150507.mat
# 7_20150715.mat
# 10_20151014.mat
# 11_20150916.mat
# 5_20160406.mat
# 9_20151028.mat
# 2_20150915.mat
# 1_20160518.mat
# 3_20150919.mat
# 4_20151111.mat
# 14_20151205.mat
# 13_20151115.mat
# (10155, 46, 1000)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 46, 1000, 16)      160
#
#  max_pooling2d_10 (MaxPoolin  (None, 46, 200, 16)      0
#  g2D)
#
# ...
