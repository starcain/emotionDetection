# %%
from functions import cnnmodel

# %%
cnnmodel(44)
# Out:
# [51, 44]
# ['5_20160406.mat', '12_20150725.mat', '7_20150715.mat', '1_20160518.mat', '15_20150508.mat', '11_20150916.mat', '3_20150919.mat', '10_20151014.mat', '14_20151205.mat', '6_20150507.mat', '2_20150915.mat', '9_20151028.mat', '8_20151103.mat', '13_20151115.mat', '4_20151111.mat']
# 5_20160406.mat
# 12_20150725.mat
# 7_20150715.mat
# 1_20160518.mat
# 15_20150508.mat
# 11_20150916.mat
# 3_20150919.mat
# 10_20151014.mat
# 14_20151205.mat
# 6_20150507.mat
# 2_20150915.mat
# 9_20151028.mat
# 8_20151103.mat
# 13_20151115.mat
# 4_20151111.mat
# (10155, 60, 1000) (10155, 4)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_15 (Conv2D)          (None, 60, 1000, 16)      160
#
#  max_pooling2d_15 (MaxPoolin  (None, 60, 200, 16)      0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 60, 200, 32)       4640
#
#  max_pooling2d_16 (MaxPoolin  (None, 60, 66, 32)       0
# ...
