# %%
from functions import cnnmodel

# %%
cnnmodel(52)
# Out:
# [51, 53]
# ['3_20150919.mat', '11_20150916.mat', '13_20151115.mat', '2_20150915.mat', '15_20150508.mat', '10_20151014.mat', '4_20151111.mat', '6_20150507.mat', '14_20151205.mat', '9_20151028.mat', '7_20150715.mat', '5_20160406.mat', '1_20160518.mat', '12_20150725.mat', '8_20151103.mat']
# 3_20150919.mat
# 11_20150916.mat
# 13_20151115.mat
# 2_20150915.mat
# 15_20150508.mat
# 10_20151014.mat
# 4_20151111.mat
# 6_20150507.mat
# 14_20151205.mat
# 9_20151028.mat
# 7_20150715.mat
# 5_20160406.mat
# 1_20160518.mat
# 12_20150725.mat
# 8_20151103.mat
# (10155, 60, 1000) (10155, 4)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 60, 1000, 16)      160
#
#  max_pooling2d_5 (MaxPooling  (None, 60, 200, 16)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 60, 200, 32)       4640
#
#  max_pooling2d_6 (MaxPooling  (None, 60, 66, 32)       0
#  2D)
# ...
